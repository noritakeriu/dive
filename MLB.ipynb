# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ｍｌｂ_df = pd.read_csv('Teams.csv')

# %%
print(mlb_df.columns.values)
# Out:
# ['yearID' 'lgID' 'teamID' 'franchID' 'divID' 'Rank' 'G' 'Ghome' 'W' 'L'
#  'DivWin' 'WCWin' 'LgWin' 'WSWin' 'R' 'AB' 'H' '2B' '3B' 'HR' 'BB' 'SO'
#  'SB' 'CS' 'HBP' 'SF' 'RA' 'ER' 'ERA' 'CG' 'SHO' 'SV' 'IPouts' 'HA' 'HRA'
#  'BBA' 'SOA' 'E' 'DP' 'FP' 'name' 'park' 'attendance' 'BPF' 'PPF'
#  'teamIDBR' 'teamIDlahman45' 'teamIDretro']

# %%
ｍｌｂ_df.head()
# Out:
#    yearID lgID teamID franchID divID  Rank   G  Ghome   W   L     ...       \
# 0    1871  NaN    BS1      BNA   NaN     3  31    NaN  20  10     ...
# 1    1871  NaN    CH1      CNA   NaN     2  28    NaN  19   9     ...
# 2    1871  NaN    CL1      CFC   NaN     8  29    NaN  10  19     ...
# 3    1871  NaN    FW1      KEK   NaN     7  19    NaN   7  12     ...
# 4    1871  NaN    NY2      NNA   NaN     5  33    NaN  16  17     ...
#
#    DP     FP                     name                          park  \
# 0 NaN  0.838     Boston Red Stockings           South End Grounds I
# 1 NaN  0.829  Chicago White Stockings       Union Base-Ball Grounds
# 2 NaN  0.814   Cleveland Forest Citys  National Association Grounds
# 3 NaN  0.803     Fort Wayne Kekiongas                Hamilton Field
# 4 NaN  0.839         New York Mutuals      Union Grounds (Brooklyn)
#
#    attendance  BPF  PPF  teamIDBR  teamIDlahman45  teamIDretro
# 0         NaN  103   98       BOS             BS1          BS1
# ...

# %%
mlb_df.tail()
# Out:
#       yearID lgID teamID franchID divID  Rank    G  Ghome   W   L  \
# 2830    2016   NL    SLN      STL     C     2  162   81.0  86  76
# 2831    2016   AL    TBA      TBD     E     5  162   81.0  68  94
# 2832    2016   AL    TEX      TEX     W     1  162   81.0  95  67
# 2833    2016   AL    TOR      TOR     E     2  162   81.0  89  73
# 2834    2016   NL    WAS      WSN     E     1  162   81.0  95  67
#
#          ...          DP     FP                  name  \
# 2830     ...       169.0  0.983   St. Louis Cardinals
# 2831     ...       129.0  0.984        Tampa Bay Rays
# 2832     ...       190.0  0.984         Texas Rangers
# 2833     ...       144.0  0.986     Toronto Blue Jays
# 2834     ...       142.0  0.988  Washington Nationals
#
#                                park  attendance  BPF  PPF  teamIDBR  \
# 2830              Busch Stadium III   3444490.0  100   99       STL
# 2831                Tropicana Field   1286163.0   93   94       TBR
# ...

# %%
mlb_df.describe()
# Out:
#             yearID         Rank            G        Ghome            W  \
# count  2835.000000  2835.000000  2835.000000  2436.000000  2835.000000
# mean   1955.681834     4.095238   150.469841    78.496305    74.814109
# std      41.767356     2.318674    23.134065     4.677657    17.591208
# min    1871.000000     1.000000     6.000000    44.000000     0.000000
# 25%    1920.000000     2.000000   154.000000    77.000000    66.000000
# 50%    1964.000000     4.000000   157.000000    81.000000    77.000000
# 75%    1993.000000     6.000000   162.000000    81.000000    87.000000
# max    2016.000000    13.000000   165.000000    84.000000   116.000000
#
#                  L            R           AB            H           2B  \
# count  2835.000000  2835.000000  2835.000000  2835.000000  2835.000000
# mean     74.814109   682.399295  5146.473369  1346.939330   228.127690
# std      17.331455   135.224393   747.595825   218.926978    58.633383
# ...

# %%
ｍｌｂ_df[['Rank', 'R']].groupby(['Rank'], as_index=False).mean().sort_values(by='R', ascending=False)
# Out:
#     Rank           R
# 0      1  768.454545
# 1      2  731.065268
# 2      3  710.637890
# 3      4  689.297619
# 4      5  661.467005
# 5      6  623.200680
# 6      7  608.304348
# 11    12  572.900000
# 7      8  572.419540
# 8      9  561.870968
# 9     10  550.846154
# 10    11  523.000000
# 12    13  146.500000

# %%
ｍｌｂ_df[['Rank', 'RA']].groupby(['Rank'], as_index=False).mean().sort_values(by='RA', ascending=False)
# Out:
#     Rank          RA
# 11    12  927.300000
# 7      8  770.695402
# 10    11  756.692308
# 6      7  732.367150
# 4      5  709.000000
# 5      6  707.023810
# 9     10  701.807692
# 3      4  697.514286
# 8      9  690.258065
# 2      3  666.352518
# 1      2  640.263403
# 0      1  614.516746
# 12    13  284.500000

# %%
ｍｌｂ_df[['Rank', 'W']].groupby(['Rank'], as_index=False).mean().sort_values(by='W', ascending=False)
# Out:
#     Rank          W
# 0      1  92.901914
# 1      2  86.102564
# 2      3  80.431655
# 3      4  74.866667
# 4      5  69.807107
# 5      6  64.741497
# 6      7  59.439614
# 8      9  52.354839
# 7      8  50.775862
# 9     10  49.192308
# 10    11  33.615385
# 11    12  31.400000
# 12    13   6.500000

# %%
ｍｌｂ_df[['Rank', 'L']].groupby(['Rank'], as_index=False).mean().sort_values(by='L', ascending=False)
# Out:
#     Rank          L
# 7      8  91.856322
# 11    12  91.400000
# 6      7  86.072464
# 5      6  83.666667
# 9     10  83.653846
# 4      5  81.451777
# 3      4  77.404762
# 8      9  75.645161
# 2      3  71.071942
# 10    11  70.846154
# 1      2  65.983683
# 0      1  59.177033
# 12    13  31.500000

# %%
ｍｌｂ_df[['Rank', 'ERA']].groupby(['Rank'], as_index=False).mean().sort_values(by='ERA', ascending=False)
# Out:
#     Rank       ERA
# 11    12  5.066000
# 10    11  4.905385
# 9     10  4.300769
# 8      9  4.289677
# 7      8  4.216092
# 6      7  4.047826
# 4      5  3.975305
# 3      4  3.908714
# 5      6  3.905374
# 2      3  3.737866
# 1      2  3.582075
# 0      1  3.438900
# 12    13  3.410000

# %%
ｍｌｂ_df[['Rank', 'H']].groupby(['Rank'], as_index=False).mean().sort_values(by='H', ascending=False)
# Out:
#     Rank            H
# 0      1  1418.265550
# 1      2  1391.601399
# 2      3  1380.014388
# 3      4  1370.938095
# 4      5  1343.319797
# 5      6  1300.176871
# 6      7  1278.961353
# 7      8  1230.287356
# 9     10  1129.076923
# 11    12  1120.600000
# 8      9  1095.354839
# 10    11   931.769231
# 12    13   257.500000

# %%
g = sns.FacetGrid(mlb_df,col='DivWin')
g.map(plt.hist,'R',bins=20)

# %%
g = sns.FacetGrid(mlb_df,col='DivWin')
g.map(plt.hist,'RA',bins=20)

# %%
sns.countplot('W',data=mlb_df,hue='WSWin')

# %%
sns.countplot('L',data=mlb_df,hue='WSWin')

# %%
sns.jointplot(x="H", y="W", data=mlb_df);

# %%
sns.jointplot(x="R", y="W", data=mlb_df);

# %%
sns.jointplot(x="HR", y="W", data=mlb_df);

# %%
sns.jointplot(x="RA", y="W", data=mlb_df);

# %%
sns.jointplot(x="ERA", y="W", data=mlb_df);
