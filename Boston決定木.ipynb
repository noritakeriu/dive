# %%
from sklearn.datasets import load_boston
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.grid_search import GridSearchCV
from sklearn.model_selection import train_test_split
# Out:
# /Users/noritakeriu/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/noritakeriu/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/sklearn/grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %% [markdown]
# データ取得

# %%
boston = load_boston()
boston
#boston.features
# Out:
# {'DESCR': "Boston House Prices dataset\n===========================\n\nNotes\n------\nData Set Characteristics:  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive\n    \n    :Median Value (attribute 14) is usually the target\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate p
# ...

# %% [markdown]
# 取得データをデータフレームにする

# %%
X = pd.DataFrame(boston.data, columns=boston.feature_names)
y = pd.DataFrame(boston.target,columns=['MEDV'])

# %% [markdown]
# 基本的なデータ探索について記述せよ
# ・このデータセットは何のデータセットであるか(何のために作成されたか、誰が作成したか、何年に作成されたか)
# ・それぞれのカラムは何を表しているのか

# %% [markdown]
# 答え：
# 米国ボストン市郊外における地域別の住宅価格のデータセット。ボストンの住宅データは1978年に収集され、506項目のそれぞれは、マサチューセッツ州ボストンの様々な郊外の家庭についての約14のフィーチャに関する集計データを表しています。
# CRIM	人口 1 人当たりの犯罪発生数
# ZN	25,000 平方フィート以上の住居区画の占める割合
# INDUS	小売業以外の商業が占める面積の割合
# CHAS	チャールズ川によるダミー変数 (1: 川の周辺, 0: それ以外)
# NOX	NOx の濃度
# RM	住居の平均部屋数
# AGE	1940 年より前に建てられた物件の割合
# DIS	5 つのボストン市の雇用施設からの距離 (重み付け済)
# RAD	環状高速道路へのアクセスしやすさ
# TAX	$10,000 ドルあたりの不動産税率の総計
# PTRATIO	町毎の児童と教師の比率
# B	町毎の黒人 (Bk) の比率を次の式で表したもの。
# LSTAT	給与の低い職業に従事する人口の割合

# %%
conbine=pd.concat([X,y], axis=1 )
conbine
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0  242.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0  311.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0  311.0
# ...

# %% [markdown]
# 一変数の可視化

# %%
conbine.describe
# Out:
# <bound method NDFrame.describe of          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0  242.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0  311.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0  311.0
# ...

# %% [markdown]
# describeメソッドを用いることで把握できたこと（考察）を記述せよ
# ・前処理に関して気をつけるべき点
# ・機械学習の手法選択に活かせること
# ・機械学習の特徴選択について考えられること

# %% [markdown]
# 答え：
# ダミー変数が入っている。各特徴量の値にレベル格差があることから、正規化・標準化するか、正規化・標準化不要な学習モデルを採用するのが望ましい。関連性の乏しい特徴量もありそうなので、全ての特徴量を使うのではなく有⽤なものを選び出す作業が必要か。特徴選択機能を含む機械学習アルゴリズム（決定⽊，ランダムフォレスト等）が望ましいかも。

# %%
conbine.info
# Out:
# <bound method DataFrame.info of          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0  242.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0  311.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0  311.0
# ...

# %%
conbine.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.199458  0.404471 -0.055295  0.417521 -0.219940  0.350784
# ZN      -0.199458  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.404471 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055295 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.417521 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219940  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.350784 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.377904  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.622029 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.579564 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.288250 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %% [markdown]
# 二変数の可視化について記述せよ　相関
# ・そもそも相関とは何か
# ・MEDVにもっとも相関があると出力された変数を3つほどあげよ
# ・相関がある変数を判明させることでどのように利用できそうか考察せよ（調査せよ）

# %% [markdown]
# 答え：
# ・相関とは、相関というのは、ふたつの特徴量の間の関連性を指す。
# ・LSTAT、RM、PTRATIO
# ・特徴選択をしなかった場合と比較して、精度が下がる。特徴選択や次元削減により特徴量の数を減らすのに役立つ。全ての特徴量量の組み合わせを試すのは困難になるときもある。

# %% [markdown]
# 相関の注意点について記述せよ
# ・相関が正しく2変数の関係を表していない時がある、それはどのような場合か
# ・その場合、どのような手段によって、確認するべきか

# %% [markdown]
# 答え：
# ・データに外れ値が混入している場合
# ・グラフ等による可視化によって外れ値を確認（除去）するべき

# %% [markdown]
# 二変数の可視化　プロット

# %%
plt.scatter(X["RM"], y,c = y,cmap='plasma')
plt.xlabel("RM")
plt.ylabel("MEDV")
plt.grid(True)

# %%
plt.scatter(X["LSTAT"], y,c = y,cmap='plasma')
plt.xlabel("LSTAT")
plt.ylabel("MEDV")
plt.grid(True)

# %%
plt.scatter(X["PTRATIO"], y,c = y,cmap='plasma')
plt.xlabel("PTRATIO")
plt.ylabel("MEDV")
plt.grid(True)

# %% [markdown]
# 二変数の可視化について記述せよ　プロット
# それぞれのプロット結果から、今回の相関はそれぞれ信用できるか記述せよ。

# %% [markdown]
# 答え：
# LSTATとRMに関しては相関を信用して良さそうだが、PTRATIOについては相関を信用することはできない。

# %% [markdown]
# データセット分割

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=1)

# %% [markdown]
# 学習

# %%
for t in (range(3)):
        reg = DecisionTreeRegressor(max_depth = t+1 )
        reg = reg.fit(X_train,y_train)
        print('train score: {:.3f}'.format(reg.score(X_train, y_train)))
        print('test score: {:.3f}'.format(reg.score(X_test, y_test)))
        t+=1
# Out:
# train score: 0.453
# test score: 0.407
# train score: 0.683
# test score: 0.744
# train score: 0.792
# test score: 0.817

# %% [markdown]
# 学習曲線

# %%
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    """
    Generate a simple plot of the test and training learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : int, cross-validation generator or an iterable, optional
        Determines the cross-validation splitting strategy.
        Possible inputs for cv are:
          - None, to use the default 3-fold cross-validation,
          - integer, to specify the number of folds.
          - An object to be used as a cross-validation generator.
          - An iterable yielding train/test splits.

        For integer/None inputs, if ``y`` is binary or multiclass,
        :class:`StratifiedKFold` used. If the estimator is not a classifier
        or if ``y`` is neither binary nor multiclass, :class:`KFold` is used.

        Refer :ref:`User Guide <cross_validation>` for the various
        cross-validators that can be used here.

    n_jobs : integer, optional
        Number of jobs to run in parallel (default 1).
    """
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")

# %%
print(__doc__)

from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit
from sklearn.tree import DecisionTreeRegressor



title = "Learning Curves (DecisionTreeRegressor)"
# Cross validation with 100 iterations to get smoother mean test and train
# score curves, each time with 20% data randomly selected as a validation set.
cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=1)

for degree in range(1,11):
    estimator = DecisionTreeRegressor(max_depth=degree)
    plot_learning_curve(estimator,title,X,y,ylim=(0.3, 1.01),cv=cv,n_jobs=4)
# Out:
# Automatically created module for IPython interactive environment

# %% [markdown]
# 学習曲線について記述せよ
# ・High varianceとは何か
# ・High Biasとは何か
# ・もっとも結果が良いと思われた深さをひとつ選択せよ
# ・なぜその深さが最も良いか記述せよ
# ・その最も結果が良いと思われる深さにおいて、データ数を増やしていくと、さらに結果は良くなるか記述せよ

# %% [markdown]
# 答え：
# ・スコアの差が大きくオーバーフィット（過学習）の状態
# ・スコアの差が小い且つスコアが低いアンダーフィット（未学習）の状態
# ・4
# ・他と比べてスコアが高く、スコアの差が小さい（High Biasの状態でなく、High varianceでもない）から
# ・データ数を増やしてもある一定以上には結果は良くならない（と推測される）。

# %% [markdown]
# グリッドサーチ

# %%
from sklearn.metrics import r2_score, make_scorer
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV

reg = DecisionTreeRegressor()
params = {"max_depth":  list(range(1,11))}
scoring_fnc=make_scorer(r2_score)
grid = GridSearchCV(estimator=reg, param_grid=params, scoring=scoring_fnc,cv=5)
grid.fit(X_train,y_train)
print(grid.best_params_)
# Out:
# {'max_depth': 6}

# %% [markdown]
# グリッドサーチについて記述せよ
# ・グリッドサーチとは何か
# ・グリッドサーチと同じようにハイパーパラメーターを探索する手法を挙げよ
# ・その手法は、グリッドサーチと比べて、どの点で優れているか、どのように使い分けるべきか

# %% [markdown]
# 答え：
# ・グリッドサーチはそれらのハイパーパラメータの組み合わせについて２次元の格子状（網目）のようにしらみつぶしに探す方法。
# ・ベイズ最適化
# ・ハイパーパラメータが非常に多い場合、グリッドサーチのための組み合わせは非常に大きくなってしまうので、正答率が良さそうなエリアを優先的に観測する（局所解に陥らないように他のエリアもたまに観測）するベイズ最適化の方が適切

# %% [markdown]
# グリッドサーチを使いこなそう
# ・グリッドサーチの際、Kfoldの折りたたみの回数を5回と設定しているが、それぞれ3回と10回に変えて検証せよ、また結果を元にどの折りたたみ回数がベストなのか考察せよ
# ・グリッドサーチにおいて評価方法を決定係数を使用していたが、平均二乗誤差に変更せよ

# %% [markdown]
# 答え：
# 精度の観点から折りたたみ回数が多い１０回をベストと考えた。折りたたみ回数３回は、得られた結果が先の学習曲線での考察結果と大きく異なるのでベストとは言い難い。５回と１０回では、５回でも精度は悪くはないが、今回はハイパーパラメーターが少ないので１０回でも計算時間も大きく変わらず精度が高くなる結果になったようである。

# %%
reg = DecisionTreeRegressor()
params = {"max_depth":  list(range(1,11))}
scoring_fnc=make_scorer(r2_score)
grid = GridSearchCV(estimator=reg, param_grid=params, scoring=scoring_fnc,cv=3)
grid.fit(X_train,y_train)
print(grid.best_params_)
# Out:
# {'max_depth': 10}

# %%
reg = DecisionTreeRegressor()
params = {"max_depth":  list(range(1,11))}
scoring_fnc=make_scorer(r2_score)
grid = GridSearchCV(estimator=reg, param_grid=params, scoring=scoring_fnc,cv=10)
grid.fit(X_train,y_train)
print(grid.best_params_)
# Out:
# {'max_depth': 5}

# %%
from sklearn.metrics import mean_squared_error

eg = DecisionTreeRegressor()
params = {"max_depth":  list(range(1,11))}
scoring_fnc=make_scorer(r2_score)
grid = GridSearchCV(estimator=reg, param_grid=params, scoring='mean_squared_error',cv=10)
grid.fit(X_train,y_train)
print(grid.best_params_)
# Out:
# /Users/noritakeriu/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /Users/noritakeriu/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /Users/noritakeriu/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/sklearn/metrics/scorer.py:90: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# ...

# %% [markdown]
# テスト

# %%
reg= DecisionTreeRegressor(max_depth=5)

# 学習・テスト
reg.fit(X_train, y_train)
print('train score: {:.3f}'.format(reg.score(X_train, y_train)))
print('test score: {:.3f}'.format(reg.score(X_test, y_test)))
# Out:
# train score: 0.923
# test score: 0.859
